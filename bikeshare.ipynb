# %%
import time
import pandas as pd
import numpy as np

# %%
CITY_DATA = { 'chicago': 'chicago.csv',
              'new york city': 'new_york_city.csv',
              'washington': 'washington.csv' }

# %%
def get_filters():
    """
    Asks user to specify a city, month, and day to analyze.
    Returns:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    """
    print('Hello! Let\'s explore some US bikeshare data!')
    # TO DO: get user input for city (chicago, new york city, washington). HINT: Use a while loop to handle invalid inputs
    #n_city = ['chicago', 'new york city', 'washington']
    
    while True :
        #city = ["chicago", "new york city", "washington"].lower()
        n_city = ['chicago', 'new york city', 'washington']
        print("which city do you want its data (chicago, new york city or washington?")
        city = input().lower()
        #city = input().lower()
        if city in CITY_DATA :
            #print("\n which city do you want its data (chicago, new york city or washington?\n")
            break
        else:
            print("\n please enter (chicago, new york city or washington \n)")
    #n_months = ['january', 'february', 'march', 'april', 'may', 'june']
    while True:
        # months = ['january', 'february', 'march', 'april', 'may', 'june']
        # month = months.index(month) + 1
        n_months = ['january', 'february', 'march', 'april', 'may', 'june']
        print("\n Which month do you want? (january ,february, ...) \n")
        month = input().lower()
        #month = input().lower()
        if month in n_months:
            #print("\n Which month do you want? \n")
            break
        else :
            print("\n please specify which month.\n")
    # TO DO: get user input for day of week (all, monday, tuesday, ... sunday)
    #n_days = ['Sunday', 'Monday','Thursday','Tuesday','Wednesday','Friday','Saturday'].lower()
    while True:
        #day = days.index(day) + 1
        n_days = ['Sunday', 'Monday','Thursday','Tuesday','Wednesday','Friday','Saturday']
        print("\n which day do you want?(Sun, Mon ,...)\n")
        day = input().lower()
        #day = input().lower()
        if day in n_days:
            #print("\n which day do you want? \n")
            break 
        else :
            print("\n  please spicify which day.\n")
    print('-'*40)
    return city, month, day

# %%
def load_data(city, month, day):
    """
    Loads data for the specified city and filters by month and day if applicable.
    Args:
        (str) city - name of the city to analyze
        (str) month - name of the month to filter by, or "all" to apply no month filter
        (str) day - name of the day of week to filter by, or "all" to apply no day filter
    Returns:
        df - Pandas DataFrame containing city data filtered by month and day
    """
    # to load data file into a dataframe
    df = pd.read_csv(CITY_DATA[city])

    # to convert the Start Time column to datetime
    df['Start Time'] = pd.to_datetime(df['Start Time'])

    # to extract month and day of week from Start Time to create new columns
    df['month'] = df['Start Time'].dt.month
    df['d_week'] = df['Start Time'].dt.weekday_name
    
    if month != 'all':
        
        months = ['january', 'february', 'march', 'april', 'may', 'june']
        month = months.index(month) + 1
        
        df = df[df['month'] == month]
     
    if day != 'all':
        
        df = df[df['d_week'] == day.title()]
    return df

# %%
def time_stats(df):
    """Displays statistics on the most frequent times of travel."""
    print('\nCalculating The Most Frequent Times of Travel...\n')
    start_time = time.time()
    # TO DO: display the most common month
    m_popular_month = df['month'].mode()[0]
    print('The most popular month is', m_popular_month)
    # TO DO: display the most common day of week
    m_popular_day = df['d_week'].mode()[0]
    print('The most popular day is',m_popular_day)

    # TO DO: display the most common start hour 
    df['Start Hour'] = df['Start Time'].dt.hour
    m_popular_hour = df['hour'].mode()[0]
    print('The most popular start hour is ', m_popular_hour)
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def station_stats(df):
    """Displays statistics on the most popular stations and trip."""
    print('\nCalculating The Most Popular Stations and Trip...\n')
    start_time = time.time()

    # TO DO: display most commonly used start station
    m_start_station = df['Start Station'].mode()[0]
    print('The most commonly used start station is', m_start_station)

    # TO DO: display most commonly used end station
    m_end_station = df['End Station'].mode()[0]
    print('The most commonly used end station is ',m_end_station )

    # TO DO: display most frequent combination of start station and end station trip
    df['trip'] =df['Start Station'] +":"+ df['End Station']
    m_pop_trip = df['trip'].mode()[0]
    print('The most frequent trip is ', m_pop_trip)
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def trip_duration_stats(df):
    """Displays statistics on the total and average trip duration."""
    print('\nCalculating Trip Duration...\n')
    start_time = time.time()
    
    # TO DO: display total travel time
    t_travel_time= df['Trip Duration'].sum()
    minute,second=divmod(t_travel_time,60)
    hour,minute=divmod(minute,60)
    print(" The total travel time is ({} hour(s){} minute(s) {} second(s)".format(hour,minute,second))

    # TO DO: display mean travel time
    m_travel_time = df['Trip Duration'].mean()
    minute,second=divmod(m_travel_time,60)
    hour,minute=divmod(minute,60)
    print(" The mean of travel time is ({} hour(s){} minute(s) {} second(s)".format(hour,minute,second))

# %%
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def user_stats(df):
    """Displays statistics on bikeshare users."""
    print('\nCalculating User Stats...\n')
    start_time = time.time()

    # TO DO: Display counts of user types
    num_users = df['User Type'].value_counts()
    print("\n The number of user types is\n", num_users)
 
    # TO DO: Display counts of gender
    try :
       num_gender= df['Gender'].value_counts()
       print("\n Number of each gender is \n",num_gender )
    except:
       print("\n There is no gender data in  Washington\n")
    # TO DO: Display earliest, most recent, and most common year of birth
    try :
        earl_birth= int(df['Birth Year'].min())
        print("\n The earliest birth year is\n",earl_birth)
        m_recent_birth = int(df['Birth Year'].max())
        print("\n The  most recent birth year is\n",m_recent_birth)
        m_common_year = int(df['Birth Year'].mode()[0])
        print("\n The   most common year of birth is\n",m_common_year)
    except :
        print("\n There is no birth year data in  Washington\n")
    print("\nThis took %s seconds." % (time.time() - start_time))
    print('-'*40)

# %%
def display_raw_data(city):
    print('\nRaw data is available to check... \n')
    print('To View the availbale raw data in chuncks of 5 rows type: Yes or No if you don\'t want \n')
    display_raw = input().lower()
    while display_raw not in ('yes', 'no'):
        print('please enter valid answer please again')
        print('To View the availbale raw data in chuncks of 5 rows type: Yes or No if you don\'t want \n')
        display_raw = input().lower()
   # The second while loop is on the same level and doesn't belong to the first.
    while display_raw == 'yes':
        try:
            for chunk in pd.read_csv(CITY_DATA[city], index_col = 0 ,chunksize=5):
                print(chunk)
                print('To View the availbale raw in chuncks of 5 rows type: Yes\n')
                display_raw = input().lower()
                if display_raw != 'yes':
                    print('Thank You')
                    break
            break
        except KeyboardInterrupt:
            print('Thank you.')

# %%
def main():
    while True:
        city, month, day = get_filters()
        df = load_data(city, month, day)
        time_stats(df)
        station_stats(df)
        trip_duration_stats(df)
        user_stats(df)
        restart = input('\nWould you like to restart? Enter yes or no.\n')
        if restart.lower() != 'yes':
            break

# %%
if __name__ == "__main__":
	main()
